# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('placement.xlsx')

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 254  6.70                    64       0
# 897  7.13                    35       1
# 853  7.74                    22       0
# 218  6.62                    52       0
# 996  9.12                    65       1

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

# %%
df['placement_exam_marks'].skew()
# Out:
# 0.8356419499466834

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 6.96124000000001
# Std value of cgpa 0.6158978751323894
# Min value of cgpa 4.89
# Max value of cgpa 9.12

# %%
# Finding the boundary values
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 8.808933625397177
# Lowest allowed 5.113546374602842

# %%
# Finding the outliers
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                    44       1
# 995  8.87                    44       1
# 996  9.12                    65       1
# 997  4.89                    34       0
# 999  4.90                    10       1

# %%
# Trimming

new_df = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                    26       1
# 1    7.46                    38       1
# 2    7.54                    40       1
# 3    6.42                     8       1
# 4    7.23                    17       0
# 5    7.30                    23       1
# 6    6.69                    11       0
# 7    7.12                    39       1
# 8    6.45                    38       0
# 9    7.75                    94       1
# 10   6.82                    16       1
# 11   6.38                     7       1
# 12   6.58                    16       1
# 13   5.68                    26       0
# 14   7.91                    43       0
# 15   7.10                    21       0
# 16   6.53                    19       0
# 17   7.56                    22       1
# 18   6.93                    27       0
# 19   7.63                    29       0
# 20   6.69                    47       0
# 21   7.43                    33       1
# 22   6.76                    54       1
# 23   6.05                    11       0
# 24   6.44                    11       0
# 25   6.28                    58       1
# 26   7.45                     8       1
# 27   6.53                    46       0
# 28   7.23                    19       0
# 29   6.51                    15       1
# ..    ...                   ...     ...
# 966  6.24                    72       1
# 967  7.35                    59       0
# 968  6.84                    26       0
# 969  6.86                    41       0
# 970  7.28                    42       1
# 971  6.69                    18       1
# 972  7.02                    18       0
# 973  6.10                    37       1
# 974  6.42                    38       0
# 975  8.43                    25       1
# 976  6.96                    48       0
# 977  7.18                    49       0
# 978  6.78                    12       0
# 979  7.00                    13       1
# 980  6.18                    27       0
# 981  8.06                    37       0
# 982  6.87                    22       0
# 983  6.81                    11       1
# 984  6.89                    16       1
# 985  7.10                    26       0
# 986  7.09                    19       1
# 987  6.77                    62       0
# 988  5.64                    37       1
# 989  6.23                    31       0
# 990  6.17                    33       1
# 991  7.04                    57       0
# 992  6.26                    12       0
# 993  6.73                    21       1
# 994  6.48                    63       0
# 998  8.62                    46       1
#
# [995 rows x 3 columns]

# %%
# Approach 2

# Calculating the Zscore

df['cgpa_zscore'] = (df['cgpa'] - df['cgpa'].mean())/df['cgpa'].std()

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed  cgpa_zscore
# 0  7.19                    26       1     0.371425
# 1  7.46                    38       1     0.809810
# 2  7.54                    40       1     0.939701
# 3  6.42                     8       1    -0.878782
# 4  7.23                    17       0     0.436371

# %%
df[df['cgpa_zscore'] > 3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 995  8.87                    44       1     3.099150
# 996  9.12                    65       1     3.505062

# %%
df[df['cgpa_zscore'] < -3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                    44       1    -3.314251
# 997  4.89                    34       0    -3.362960
# 999  4.90                    10       1    -3.346724

# %%
df[(df['cgpa_zscore'] > 3) | (df['cgpa_zscore'] < -3)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                    44       1    -3.314251
# 995  8.87                    44       1     3.099150
# 996  9.12                    65       1     3.505062
# 997  4.89                    34       0    -3.362960
# 999  4.90                    10       1    -3.346724

# %%
# Trimming 
new_df = df[(df['cgpa_zscore'] < 3) & (df['cgpa_zscore'] > -3)]

# %%
new_df
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                    26       1     0.371425
# 1    7.46                    38       1     0.809810
# 2    7.54                    40       1     0.939701
# 3    6.42                     8       1    -0.878782
# 4    7.23                    17       0     0.436371
# 5    7.30                    23       1     0.550026
# 6    6.69                    11       0    -0.440398
# 7    7.12                    39       1     0.257770
# 8    6.45                    38       0    -0.830073
# 9    7.75                    94       1     1.280667
# 10   6.82                    16       1    -0.229324
# 11   6.38                     7       1    -0.943728
# 12   6.58                    16       1    -0.618999
# 13   5.68                    26       0    -2.080280
# 14   7.91                    43       0     1.540450
# 15   7.10                    21       0     0.225297
# 16   6.53                    19       0    -0.700181
# 17   7.56                    22       1     0.972174
# 18   6.93                    27       0    -0.050723
# 19   7.63                    29       0     1.085829
# 20   6.69                    47       0    -0.440398
# 21   7.43                    33       1     0.761100
# 22   6.76                    54       1    -0.326742
# 23   6.05                    11       0    -1.479531
# 24   6.44                    11       0    -0.846309
# 25   6.28                    58       1    -1.106092
# 26   7.45                     8       1     0.793573
# 27   6.53                    46       0    -0.700181
# 28   7.23                    19       0     0.436371
# 29   6.51                    15       1    -0.732654
# ..    ...                   ...     ...          ...
# 966  6.24                    72       1    -1.171038
# 967  7.35                    59       0     0.631209
# 968  6.84                    26       0    -0.196851
# 969  6.86                    41       0    -0.164378
# 970  7.28                    42       1     0.517553
# 971  6.69                    18       1    -0.440398
# 972  7.02                    18       0     0.095405
# 973  6.10                    37       1    -1.398349
# 974  6.42                    38       0    -0.878782
# 975  8.43                    25       1     2.384746
# 976  6.96                    48       0    -0.002013
# 977  7.18                    49       0     0.355189
# 978  6.78                    12       0    -0.294270
# 979  7.00                    13       1     0.062933
# 980  6.18                    27       0    -1.268457
# 981  8.06                    37       0     1.783997
# 982  6.87                    22       0    -0.148141
# 983  6.81                    11       1    -0.245560
# 984  6.89                    16       1    -0.115669
# 985  7.10                    26       0     0.225297
# 986  7.09                    19       1     0.209061
# 987  6.77                    62       0    -0.310506
# 988  5.64                    37       1    -2.145226
# 989  6.23                    31       0    -1.187275
# 990  6.17                    33       1    -1.284694
# 991  7.04                    57       0     0.127878
# 992  6.26                    12       0    -1.138565
# 993  6.73                    21       1    -0.375452
# 994  6.48                    63       0    -0.781363
# 998  8.62                    46       1     2.693239
#
# [995 rows x 4 columns]

# %%
# Capping
upper_limit = df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit = df['cgpa'].mean() - 3*df['cgpa'].std()

# %%
lower_limit
# Out:
# 5.113546374602842

# %%
df['cgpa'] = np.where(
    df['cgpa']>upper_limit,
    upper_limit,
    np.where(
        df['cgpa']<lower_limit,
        lower_limit,
        df['cgpa']
    )
)

# %%
df.shape
# Out:
# (1000, 4)

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961499
# std         0.612688
# min         5.113546
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         8.808934
# Name: cgpa, dtype: float64
